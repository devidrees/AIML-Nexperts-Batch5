# %% [markdown]
# Customer Segmentation Project
#
# Mall Customers dataset
# we will implement K means clustering to check the spending patterns of our customers
# segment the customer spending behaviour
# Task:
#
# 1. Data ingestion/acquisition
# 2. Data EDA
# 3. Preprocessing, if needed
# 4. Train a model
# 5. Cluster the users
#
# Optional 6. Tag each cluter with a name and save that column in dataframe

# %%
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.cluster import KMeans


url = "https://raw.githubusercontent.com/tirthajyoti/Machine-Learning-with-Python/master/Datasets/Mall_Customers.csv"

df = pd.read_csv(url)
df
# Out:
#      CustomerID  Gender  Age  Annual Income (k$)  Spending Score (1-100)
# 0             1    Male   19                  15                      39
# 1             2    Male   21                  15                      81
# 2             3  Female   20                  16                       6
# 3             4  Female   23                  16                      77
# 4             5  Female   31                  17                      40
# ..          ...     ...  ...                 ...                     ...
# 195         196  Female   35                 120                      79
# 196         197  Female   45                 126                      28
# 197         198    Male   32                 126                      74
# 198         199    Male   32                 137                      18
# 199         200    Male   30                 137                      83
#
# [200 rows x 5 columns]

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 200 entries, 0 to 199
# Data columns (total 5 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   CustomerID              200 non-null    int64
#  1   Gender                  200 non-null    str
#  2   Age                     200 non-null    int64
#  3   Annual Income (k$)      200 non-null    int64
#  4   Spending Score (1-100)  200 non-null    int64
# dtypes: int64(4), str(1)
# memory usage: 7.9 KB

# %%
##Data Cleaning bcs have non numerical column and remove the id bcs its sequential
#use one hot encoding

df_cleaned = df.drop(columns=['CustomerID'])
df_encoded = pd.get_dummies(df_cleaned, columns=['Gender'], dtype=int)
df_encoded

#scale
from scipy.stats import zscore

df_scaled = df_encoded.apply(zscore)
df_scaled
# Out:
#           Age  Annual Income (k$)  Spending Score (1-100)  Gender_Female  \
# 0   -1.424569           -1.738999               -0.434801      -1.128152
# 1   -1.281035           -1.738999                1.195704      -1.128152
# 2   -1.352802           -1.700830               -1.715913       0.886405
# 3   -1.137502           -1.700830                1.040418       0.886405
# 4   -0.563369           -1.662660               -0.395980       0.886405
# ..        ...                 ...                     ...            ...
# 195 -0.276302            2.268791                1.118061       0.886405
# 196  0.441365            2.497807               -0.861839       0.886405
# 197 -0.491602            2.497807                0.923953      -1.128152
# 198 -0.491602            2.917671               -1.250054      -1.128152
# 199 -0.635135            2.917671                1.273347      -1.128152
#
#      Gender_Male
# 0       1.128152
# 1       1.128152
# 2      -0.886405
# 3      -0.886405
# 4      -0.886405
# ..           ...
# 195    -0.886405
# 196    -0.886405
# 197     1.128152
# 198     1.128152
# 199     1.128152
#
# [200 rows x 5 columns]

# %%
# Elbow Method

errors = []

for k in range(1, 13):
    kmeans = KMeans(n_clusters = k, random_state= 42)
    kmeans.fit(df_scaled)
    errors.append(kmeans.inertia_)

plt.plot(range(1,13), errors, marker = 'o')
plt.grid()
plt.show()

# %%
model_kmeans = KMeans(
    n_clusters = 5, # based on elbow
    init = 'random',
    random_state = 42
)

model_kmeans
# Out:
# KMeans(init='random', n_clusters=5, random_state=42)

# %% [markdown]
# KMeans(init='random', n_clusters=5, random_state=42)
# In a Jupyter environment, please rerun this cell to show the HTML representation or trust the notebook.
# On GitHub, the HTML representation is unable to render, please try loading this page with nbviewer.org.

# %%
df_scaled['KClustering'] = model_kmeans.fit_predict(df_scaled)
df_scaled
# Out:
#           Age  Annual Income (k$)  Spending Score (1-100)  Gender_Female  \
# 0   -1.424569           -1.738999               -0.434801      -1.128152
# 1   -1.281035           -1.738999                1.195704      -1.128152
# 2   -1.352802           -1.700830               -1.715913       0.886405
# 3   -1.137502           -1.700830                1.040418       0.886405
# 4   -0.563369           -1.662660               -0.395980       0.886405
# ..        ...                 ...                     ...            ...
# 195 -0.276302            2.268791                1.118061       0.886405
# 196  0.441365            2.497807               -0.861839       0.886405
# 197 -0.491602            2.497807                0.923953      -1.128152
# 198 -0.491602            2.917671               -1.250054      -1.128152
# 199 -0.635135            2.917671                1.273347      -1.128152
#
#      Gender_Male  KClustering
# 0       1.128152            1
# 1       1.128152            1
# 2      -0.886405            4
# 3      -0.886405            4
# 4      -0.886405            4
# ..           ...          ...
# 195    -0.886405            0
# 196    -0.886405            3
# 197     1.128152            1
# 198     1.128152            2
# 199     1.128152            1
#
# [200 rows x 6 columns]

# %%
df_scaled['Annual Income (k$)'].min()
# Out:
# np.float64(-1.7389991930659485)

# %%
plt.scatter(df_scaled['Annual Income (k$)'],df_scaled['Spending Score (1-100)'], c = df_scaled['KClustering'])
plt.show()

# %%
cluster_names = {
    0: "Normal",
    1: "High Income, High Spending",
    2: "Low Income, High Spending",
    3: "High Income, Low Spending",
    4: "Low Income, Low Spending"
}

df_scaled["Customer Type"] = df_scaled["KClustering"].map(cluster_names)
df_scaled.sample(7)
# Out:
#           Age  Annual Income (k$)  Spending Score (1-100)  Gender_Female  \
# 65  -1.496335           -0.479408                0.341630      -1.128152
# 36   0.226065           -1.013780               -1.288876       0.886405
# 120 -0.850435            0.245811                0.225165      -1.128152
# 103 -0.922202            0.054964                0.186343      -1.128152
# 124 -1.137502            0.360319               -0.823017       0.886405
# 27  -0.276302           -1.242797                0.419273      -1.128152
# 163 -0.563369            0.780183                1.661563       0.886405
#
#      Gender_Male  KClustering               Customer Type
# 65      1.128152            1  High Income, High Spending
# 36     -0.886405            3   High Income, Low Spending
# 120     1.128152            1  High Income, High Spending
# 103     1.128152            1  High Income, High Spending
# 124    -0.886405            4    Low Income, Low Spending
# 27      1.128152            1  High Income, High Spending
# 163    -0.886405            0                      Normal
