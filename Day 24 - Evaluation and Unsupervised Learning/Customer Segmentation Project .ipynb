# %% [markdown]
# ## Customer Segmentation Project
# -

# %% [markdown]
# - Mall Customers dataset
# - we will implement K means clustering to check the spending patterns of our customers
# - segment the customer spending behaviour

# %% [markdown]
# Task:
# 1. data ingestion/acquisition
# 2. Data EDA
# 3. Preprocessing, if needed
# 4. train a model
# 5. Cluster the users
#
# Optional -
#
# 6. Tag each cluter with a name and save that column in dataframe

# %%
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.cluster import KMeans


url = "https://raw.githubusercontent.com/tirthajyoti/Machine-Learning-with-Python/master/Datasets/Mall_Customers.csv"

df = pd.read_csv(url)
df.head()
# Out:
#    CustomerID  Gender  Age  Annual Income (k$)  Spending Score (1-100)
# 0           1    Male   19                  15                      39
# 1           2    Male   21                  15                      81
# 2           3  Female   20                  16                       6
# 3           4  Female   23                  16                      77
# 4           5  Female   31                  17                      40

# %%
{
    0: "Average",
    1: "VIP - High Income / High Spend",
    2: "Careful Saver - High Income / Low Spend",
    3: "Careless Spender - Low Income / High Spend",
    4: "Cautious - Low Income /Low Spend"
}
