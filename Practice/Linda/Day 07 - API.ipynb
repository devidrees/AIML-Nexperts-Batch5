# %%
data ["results"] [0] ["location"] ["city"]

data ["results"] [0] ["location"] ["country"]

# %%
import requests
random_user_url = "https://randomuser.me/api/"

requests.get (random_user_url).json ()

title_name = data["results"] [0] ["name"] ["title"]
first_name = data["results"] [0] ["name"] ["first"]
last_name =  data["results"] [0] ["name"] ["last"]

# Location (City & Country)
city = data ["results"] [0] ["location"] ["city"]
country = data ["results"] [0] ["location"] ["country"]

# sample response looks like
name = f"{title_name} {first_name} {last_name}"
print(name , "from" , city, ","  , country)
print("City: ", city)
print("Country: ", country)

# # sample response looks like
# name = data["results"][0]["name"]["title"]
# residence = "Wollongong Australia" # city and country
# email = 'ross.daniels@example.com'

# print(f"The person is: {name}\nLives in: {residence}\nEmail: {email}")

# print(f"The person is:  {name}\n Lives in:  {residence}\n Email:  {email}")
# Out:
# Miss Silviana Castro from Londrina , Brazil
# City:  Londrina
# Country:  Brazil

# %%
title_name = data["results"][0]["name"]["first"]

first_name = data["results"][0]["name"]["first"]

last_name = data["results"][0]["name"]["last"]

# %%
import requests

random_user_url = "https://randomuser.me/api/"

for i in range(4):  # number of users you want
    data = requests.get(random_user_url).json()

    title = data["results"][0]["name"]["title"]
    first = data["results"][0]["name"]["first"]
    last = data["results"][0]["name"]["last"]

    name = f"{title} {first} {last}"
    print(name)
# Out:
# Miss Stacy Richards
# Mrs Méline Leroux
# Mr Kasper Salo
# Miss Silviana Castro
