# %% [markdown]
# ## EDA (Exploratory Data Analysis) with Pandas
#
# - 1st step in data analysis & ML too
# - 3 parts -
#     1. Data Cleaning - identify & remove missing values
#     2. Data Summarisation check the dataset-
#     3. Data Visualisation -
# -  one of
#
# - Some methods that we can run on dataframes
# - Basic Inspection methods: (Data Summarization)
#     - `df.head()` - give you the first 5 elements
#         - an argument of 10 will give you first 10 elements
#     - df.tail() - last 5 but argument can change the number
#     - `df.sample()` - one random entry from the dataset
#         - an argument can change that number too
#         - we use this to check how our datasets look like inside
# - Basic attributes of a dataframe:
#     - `df.shape` - tells you the shape of the df --- how many elements along how many axes
#     - df.size - how many elements there are
#     - df.ndim - will tell you the number of axes there are in the df --- generally just 2
#     - `df.dtypes` - will tell you the data type of each column
#
#
#
# - Methods for Statistical information as well:
#     - `df.info()` - general information about the df
#         - how many records, how many columns, what is the data type of those columns
#         - also gives an idea of if there are any missing values in data
#     - `df.describe()` - gives us the statistical measurements of the columns like count, mean, min, max, std, percentiles
# -

# %%
#df.head(10)
#df.tail()
#df.sample(4)

#df.shape
#df.size 
#df.dtypes

#df.info()

#df.describe()
# Out:
#     group            stage       team1       team2              venue  \
# 99    NaN    Quarter-final         QF7         QF8        NRG Stadium
# 100   NaN       Semi-final         SF1         SF2       AT&T Stadium
# 101   NaN       Semi-final         SF3         SF4    MetLife Stadium
# 102   NaN  3rd Place Match   3rd Place   3rd Place  Hard Rock Stadium
# 103   NaN            Final  Finalist 1  Finalist 2    MetLife Stadium
#
#                 city country        date kickoff_et team1_confederation  \
# 99           Houston     USA  2026-07-11        TBD                 NaN
# 100        Arlington     USA  2026-07-14        TBD                 NaN
# 101  East Rutherford     USA  2026-07-15        TBD                 NaN
# 102            Miami     USA  2026-07-18        TBD                 NaN
# 103  East Rutherford     USA  2026-07-19        TBD                 NaN
#
#      team1_fifa_rank team1_coach team2_confederation  team2_fifa_rank  \
# ...

# %%
import pandas as pd
df = pd.read_csv('wc_2026.csv')
display(df)
# Out:
#     group            stage        team1         team2              venue  \
# 0       A      Group Stage       Mexico  South Africa     Estadio Azteca
# 1       A      Group Stage  South Korea       Czechia      Estadio Akron
# 2       A      Group Stage  South Korea        Mexico      Estadio Akron
# 3       A      Group Stage      Czechia  South Africa      Estadio Akron
# 4       A      Group Stage      Czechia        Mexico     Estadio Azteca
# ..    ...              ...          ...           ...                ...
# 99    NaN    Quarter-final          QF7           QF8        NRG Stadium
# 100   NaN       Semi-final          SF1           SF2       AT&T Stadium
# 101   NaN       Semi-final          SF3           SF4    MetLife Stadium
# 102   NaN  3rd Place Match    3rd Place     3rd Place  Hard Rock Stadium
# 103   NaN            Final   Finalist 1    Finalist 2    MetLife Stadium
#
#                 city country        date kickoff_et team1_confederation  \
# ...

# %% [markdown]
# ### Filtering
# - filter rows & columns
# - uses boolean indexing
# - keep only the rows you care about
#
# - df[condition] # or mask

# %%
df.head()
# Out:
#   group        stage        team1         team2           venue         city  \
# 0     A  Group Stage       Mexico  South Africa  Estadio Azteca  Mexico City
# 1     A  Group Stage  South Korea       Czechia   Estadio Akron  Guadalajara
# 2     A  Group Stage  South Korea        Mexico   Estadio Akron  Guadalajara
# 3     A  Group Stage      Czechia  South Africa   Estadio Akron  Guadalajara
# 4     A  Group Stage      Czechia        Mexico  Estadio Azteca  Mexico City
#
#   country        date kickoff_et team1_confederation  team1_fifa_rank  \
# 0  Mexico  2026-06-11   20:00 ET            CONCACAF             15.0
# 1  Mexico  2026-06-11   22:00 ET                 AFC             25.0
# 2  Mexico  2026-06-18   21:00 ET                 AFC             25.0
# 3  Mexico  2026-06-18   18:00 ET                UEFA             41.0
# 4  Mexico  2026-06-24   21:00 ET                UEFA             41.0
#
#       team1_coach team2_confederation  team2_fifa_rank     team2_coach
# ...

# %%
import pandas as pd
# show me the matches played in Canada
# mask = df["Country"] == "Canada"
# df[mask]
df[df["country"] == "Canada"]
# Out:
#    group        stage                   team1                   team2  \
# 6      B  Group Stage                  Canada  Bosnia and Herzegovina
# 8      B  Group Stage             Switzerland  Bosnia and Herzegovina
# 9      B  Group Stage                  Canada                   Qatar
# 10     B  Group Stage             Switzerland                  Canada
# 11     B  Group Stage  Bosnia and Herzegovina                   Qatar
# 67     L  Group Stage                   Ghana                  Panama
# 69     L  Group Stage                 Croatia                  Panama
# 83   NaN  Round of 32                      1L                      2K
# 84   NaN  Round of 32             Best 3rd #1             Best 3rd #2
#
#         venue       city country        date kickoff_et team1_confederation  \
# 6   BMO Field    Toronto  Canada  2026-06-12   15:00 ET            CONCACAF
# 8    BC Place  Vancouver  Canada  2026-06-18   15:00 ET                UEFA
# ...

# %%
# Q2 : give me data for the matches in which team1_fifa_rank was <=10
df[df["team1_fifa_rank"] <= 10]
# Out:
#    group        stage        team1         team2                    venue  \
# 12     C  Group Stage       Brazil       Morocco          MetLife Stadium
# 14     C  Group Stage       Brazil      Scotland          MetLife Stadium
# 15     C  Group Stage      Morocco         Haiti          MetLife Stadium
# 17     C  Group Stage      Morocco         Haiti         Gillette Stadium
# 24     E  Group Stage      Germany       Curaçao              NRG Stadium
# 26     E  Group Stage      Germany   Ivory Coast              NRG Stadium
# 30     F  Group Stage  Netherlands         Japan             AT&T Stadium
# 32     F  Group Stage  Netherlands        Sweden              NRG Stadium
# 36     G  Group Stage      Belgium         Egypt              Lumen Field
# 38     G  Group Stage      Belgium          Iran             SoFi Stadium
# 42     H  Group Stage        Spain    Cape Verde    Mercedes-Benz Stadium
# 44     H  Group Stage        Spain  Saudi Arabia            Estadio Akron
# ...

# %%
#Q3 : give me data for the matches in which both team were <10 fifa rank

df[(df["team1_fifa_rank"] < 10) & (df["team2_fifa_rank"] < 10)]
# Out:
#    group        stage   team1    team2            venue             city  \
# 12     C  Group Stage  Brazil  Morocco  MetLife Stadium  East Rutherford
#
#    country        date kickoff_et team1_confederation  team1_fifa_rank  \
# 12     USA  2026-06-13   18:00 ET            CONMEBOL              6.0
#
#        team1_coach team2_confederation  team2_fifa_rank     team2_coach
# 12  Dorival Júnior                 CAF              8.0  Walid Regragui

# %%
# Q4 : Find all matches where Mexico is playing
# specially as team1, AND the venue is "Estadio Azteca"

df[(df["team1"] == "Mexico") & (df["venue"] == "Estadio Azteca")]
# Out:
#   group        stage   team1         team2           venue         city  \
# 0     A  Group Stage  Mexico  South Africa  Estadio Azteca  Mexico City
#
#   country        date kickoff_et team1_confederation  team1_fifa_rank  \
# 0  Mexico  2026-06-11   20:00 ET            CONCACAF             15.0
#
#       team1_coach team2_confederation  team2_fifa_rank team2_coach
# 0  Javier Aguirre                 CAF             60.0  Hugo Broos

# %%
# Question 5: Write the code to find all matches played in either "Toronto" OR "Vancouver"
df[(df["city"] == "Toronto") | (df["city"] == "Vancouver")].shape
# Out:
# (9, 15)

# %%
# Question 6: Write a single line of pandas code to find matches where:
# team1 is ranked strictly better (lower number) than team2 AND
# The match is either in Mexico OR Canada
df[(df["team1_fifa_rank"] < df["team2_fifa_rank"]) & ((df["country"] == "Mexico") | (df["country"] == "Canada"))]

# team1_better = df['team1_fifa_rank'] < df['team2_fifa_rank']
# match_mex_can = (df['country'] == "Mexico") | (df['country'] == "Canada")
# df[team1_better & match_mex_can]

#df[(
    #(df["team1_fifa_rank"] < df["team2_fifa_rank"]) &
   # (
   #     (df["country"] == "Mexico") |
    #    (df["country"] == "Canada")))]
# Out:
#    group        stage        team1                   team2           venue  \
# 0      A  Group Stage       Mexico            South Africa  Estadio Azteca
# 1      A  Group Stage  South Korea                 Czechia   Estadio Akron
# 3      A  Group Stage      Czechia            South Africa   Estadio Akron
# 6      B  Group Stage       Canada  Bosnia and Herzegovina       BMO Field
# 8      B  Group Stage  Switzerland  Bosnia and Herzegovina        BC Place
# 9      B  Group Stage       Canada                   Qatar        BC Place
# 10     B  Group Stage  Switzerland                  Canada        BC Place
# 31     F  Group Stage       Sweden                 Tunisia    Estadio BBVA
# 44     H  Group Stage        Spain            Saudi Arabia   Estadio Akron
# 69     L  Group Stage      Croatia                  Panama       BMO Field
#
#            city country        date kickoff_et team1_confederation  \
# 0   Mexico City  Mexico  2026-06-11   20:00 ET            CONCACAF
# ...

# %%
import pandas as pd
df = pd.read_csv('wc_2026.csv')
# display(df)

# Q7 : 

mask = df[(df["team1_fifa_rank"] < df["team2_fifa_rank"]) & ((df["country"] == "Mexico") | (df["country"] == "Canada"))]
mask
# mask = True Rows
# using .loc to target
df.loc[mask, ["team1", "team2", "country"]]

# sorting data in data frames
df2.sort_values(by = "team1", ascending = False)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[27], line 11
#       7 mask = df[(df["team1_fifa_rank"] < df["team2_fifa_rank"]) & ((df["country"] == "Mexico") | (df["country"] == "Canada"))]
#       8 mask
#       9 # mask = True Rows
#      10 # using .loc to target
# ---> 11 df.loc[mask, ["team1", "team2", "country"]]
#      12
#      13 # sorting data in data frames
#      14 df2.sort_values(by = "team1", ascending = False)
#
# File ~\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages\pandas\core\indexing.py:1200, in _LocationIndexer.__getitem__(self, key)
#    1198     if self._is_scalar_access(key):
#    1199         return self.obj._get_value(*key, takeable=self._takeable)
# -> 1200     return self._getitem_tuple(key)
#    1201 else:
#    1202     # we by definition only have the 0th axis
#    1203     axis = self.axis or 0
#
# ...

# %% [markdown]
# ### sorting Data in DFs
#
# - highest numbers or

# %% [markdown]
# ### Aggregration
# - sometimes we need to get aggregate values of columns
# - methods : sum(), min(), max(), mean()
#
# - AXIS --- 0 >>>> of columns wise
# - AXIS --- 1 >>>> of rows wise

# %% [markdown]
# # use of axis argument 3 places:
# - "AGGREGATES" numpy 2D array & DataFrames
#     - axis = 0 ---> columns wise aggregates
#     - axis = 1 ---> row wise aggregates
#
# - "DROP" a column or row in dataframes
#     - axis = 0 ---> drop ROW (melintang)
#     - axis = 1 ---> drop COLUMN (menegak)

# %% [markdown]
# - Series.agg(['mean','max','min', 'count', 'sum', 'std', 'var','prod'])

# %%
# Drop all missing values
# Row with a single NaN value --- is dropped
df.dropna(inplace = True) # Original will be affected
 
# df.info()
 
# give me an aggregate for the two columns

df[['team1_fifa_rank', 'team2_fifa_rank']].min(axis = 0)

# give me an aggregate for the all the 72 rows
 
df[['team1_fifa_rank', 'team2_fifa_rank']].min(axis = 1)
# Out:
# 0     15.0
# 1     25.0
# 2     15.0
# 3     41.0
# 4     15.0
#       ...
# 67    53.0
# 68     4.0
# 69    11.0
# 70     4.0
# 71    11.0
# Length: 72, dtype: float64

# %%
df["team2_fifa_rank"].agg(["mean","min","max","count","std","var"])
# Out:
# mean      37.916667
# min        1.000000
# max       95.000000
# count     72.000000
# std       23.836739
# var      568.190141
# Name: team2_fifa_rank, dtype: float64

# %%
import pandas as pd 
# df = pd.DataFrame()
df_emp = pd.read_csv("employees.csv")
df_emp
# Out:
#       Name   Department  Salary  Experience
# 0    Alice  Engineering   75000           3
# 1      Bob    Marketing   65000           5
# 2  Charlie  Engineering   80000           7
# 3    Diana           HR   60000           2
# 4      Eve    Marketing   70000           4

# %%
df_emp[['Salary','Experience']].mean(axis = 0) # axis = 0  Column wise

df_emp[['Salary','Experience']].mean(axis = 1) # ROW WISE aggregates
# Out:
# 0    37501.5
# 1    32502.5
# 2    40003.5
# 3    30001.0
# 4    35002.0
# dtype: float64

# %%
import pandas as pd
df = pd.read_csv('wc_2026.csv')

df.team1_fifa_rank.min()

#df[["team1_fifa_rank", "team2_fifa_rank"]].mean()
#df[["team1_fifa_rank", "team2_fifa_rank"]].max()
#df[["team1_fifa_rank", "team2_fifa_rank"]].min()
#df[["team1_fifa_rank", "team2_fifa_rank"]].median()
df[["team1_fifa_rank", "team2_fifa_rank"]].mean(axis = 0) # cloumn wise
#df[["team1_fifa_rank", "team2_fifa_rank"]].mean(axis = 1) # cloumn wise
#df[["team1_fifa_rank", "team2_fifa_rank"]].mode()
#df[["team1_fifa_rank", "team2_fifa_rank"]].mode().iloc[0]
# Out:
# team1_fifa_rank    30.208333
# team2_fifa_rank    37.916667
# dtype: float64

# %%
df[(df["team1_fifa_rank"]==1) | (df["team2_fifa_rank"]==1)]
# Out:
#    group        stage   team1    team2                    venue  \
# 48     I  Group Stage  France  Senegal          MetLife Stadium
# 50     I  Group Stage  France     Iraq  Lincoln Financial Field
# 52     I  Group Stage  Norway   France          MetLife Stadium
#
#                city country        date kickoff_et team1_confederation  \
# 48  East Rutherford     USA  2026-06-16   15:00 ET                UEFA
# 50     Philadelphia     USA  2026-06-22   17:00 ET                UEFA
# 52  East Rutherford     USA  2026-06-26   15:00 ET                UEFA
#
#     team1_fifa_rank       team1_coach team2_confederation  team2_fifa_rank  \
# 48              1.0  Didier Deschamps                 CAF             14.0
# 50              1.0  Didier Deschamps                 AFC             61.0
# 52             44.0   Ståle Solbakken                UEFA              1.0
#
#          team2_coach
# 48       Aliou Cissé
# 50     Graham Arnold
# 52  Didier Deschamps

# %% [markdown]
# ## Grouping
# - group the data by some category
# - "df.groupbt("category)["col1,col2,col2,...].aggregation()"
#
# - using df.groupy('category').count() - will give you all the columns for each row
# - using df.groupy('category').szie() - will give you only the categories and their count

# %%
df_emp.head()
# Out:
#       Name   Department  Salary  Experience
# 0    Alice  Engineering   75000           3
# 1      Bob    Marketing   65000           5
# 2  Charlie  Engineering   80000           7
# 3    Diana           HR   60000           2
# 4      Eve    Marketing   70000           4

# %%
print(df_emp.groupby("Department"))

print(df_emp.groupby("Department").head)

df_emp.groupby("Department")["Salary"].count()

df_emp.groupby("Department")[["Salary", "Experience"]].count()

df_emp.groupby("Department")[["Name", "Salary", "Experience"]].count()
# Out:
# ...
# <bound method GroupBy.head of <pandas.api.typing.DataFrameGroupBy object at 0x00000248A14D1B70>>
#              Name  Salary  Experience
# Department
# Engineering     2       2           2
# HR              1       1           1
# Marketing       2       2           2

# %%
df
# how many appearances has mexico made
df.groupby("country").count()
# same below 
df.groupby("country").size()
# Out:
# country
# Canada     7
# Mexico    12
# USA       53
# dtype: int64

# %% [markdown]
# ## combine DataFrames
# - two dataframe & want to combine together
#
#
# JOINS -
#
# - are used to combine two tables
# - this happens along a KEY column ---> PRIMARY KEY --- we cover this in SQL

# %%
# Student info
students = {
    "StudentID": [1, 2, 3],
    "Student": ["Aman", "Sara", "John"]
}
df_students = pd.DataFrame(students)
display(df_students)

# Marks info
marks = {
    "StudentID": [2, 3, 4],
    "Math": [85, 90, 78],
    "English": [88, 92, 80]
}
df_marks = pd.DataFrame(marks)
display(df_marks)
# Out:
#    StudentID Student
# 0          1    Aman
# 1          2    Sara
# 2          3    John
#    StudentID  Math  English
# 0          2    85       88
# 1          3    90       92
# 2          4    78       80

# %%
# Merge
# INNER JOIN 
df_merged_IJ = pd.merge(df_students, df_marks, on = "StudentID", how = 'inner')
# `on` will be a column that is inside both tables, and each row in this column, should be unique 

# All ID elements should match

df_merged_IJ
# Out:
#    StudentID Student  Math  English
# 0          2    Sara    85       88
# 1          3    John    90       92

# %%
# LEFT JOIN
df_merged_LJ = pd.merge(df_students, df_marks, on = "StudentID", how = 'left')
df_merged_LJ
# Out:
#    StudentID Student  Math  English
# 0          1    Aman   NaN      NaN
# 1          2    Sara  85.0     88.0
# 2          3    John  90.0     92.0

# %%
# RIGHT JOIN
df_merged_RJ = pd.merge(df_students, df_marks, on = "StudentID", how = 'right')
df_merged_RJ
# Out:
#    StudentID Student  Math  English
# 0          2    Sara    85       88
# 1          3    John    90       92
# 2          4     NaN    78       80

# %%
# OUTER JOIN
df_merged_FJ = pd.merge(df_students, df_marks, on = "StudentID", how = 'outer')
df_merged_FJ
# Out:
#    StudentID Student  Math  English
# 0          1    Aman   NaN      NaN
# 1          2    Sara  85.0     88.0
# 2          3    John  90.0     92.0
# 3          4     NaN  78.0     80.0

# %%
# CONCAT
# Put one table next to the other or On top of the other

pd.concat([df_students,df_marks], ignore_index = False)
# Out:
#    StudentID Student  Math  English
# 0          1    Aman   NaN      NaN
# 1          2    Sara   NaN      NaN
# 2          3    John   NaN      NaN
# 0          2     NaN  85.0     88.0
# 1          3     NaN  90.0     92.0
# 2          4     NaN  78.0     80.0
