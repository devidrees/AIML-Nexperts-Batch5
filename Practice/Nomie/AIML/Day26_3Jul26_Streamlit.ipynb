# %%
# !pip install streamlit
# Out:
# Requirement already satisfied: streamlit in C:\Users\Surface Laptop 4\AppData\Local\Programs\Python\Python314\Lib\site-packages (1.58.0)
# Requirement already satisfied: altair!=5.4.0,!=5.4.1,<7,>=4.0 in C:\Users\Surface Laptop 4\AppData\Local\Programs\Python\Python314\Lib\site-packages (from streamlit) (6.2.2)
# Requirement already satisfied: blinker<2,>=1.5.0 in C:\Users\Surface Laptop 4\AppData\Local\Programs\Python\Python314\Lib\site-packages (from streamlit) (1.9.0)
# Requirement already satisfied: cachetools<8,>=5.5 in C:\Users\Surface Laptop 4\AppData\Local\Programs\Python\Python314\Lib\site-packages (from streamlit) (7.1.4)
# Requirement already satisfied: click<9,>=7.0 in C:\Users\Surface Laptop 4\AppData\Local\Programs\Python\Python314\Lib\site-packages (from streamlit) (8.4.2)
# Requirement already satisfied: gitpython!=3.1.19,<4,>=3.0.7 in C:\Users\Surface Laptop 4\AppData\Local\Programs\Python\Python314\Lib\site-packages (from streamlit) (3.1.50)
# Requirement already satisfied: numpy<3,>=1.23 in C:\Users\Surface Laptop 4\AppData\Local\Programs\Python\Python314\Lib\site-packages (from streamlit) (2.5.0)
# Requirement already satisfied: packaging>=20 in C:\Users\Surface Laptop 4\AppData\Local\Programs\Python\Python314\Lib\site-packages (from streamlit) (26.2)
# Requirement already satisfied: pandas<4,>=1.4.0 in C:\Users\Surface Laptop 4\AppData\Local\Programs\Python\Python314\Lib\site-packages (from streamlit) (3.0.3)
# Requirement already satisfied: pillow<13,>=7.1.0 in C:\Users\Surface Laptop 4\AppData\Local\Programs\Python\Python314\Lib\site-packages (from streamlit) (12.3.0)
# Requirement already satisfied: pydeck<1,>=0.8.0b4 in C:\Users\Surface Laptop 4\AppData\Local\Programs\Python\Python314\Lib\site-packages (from streamlit) (0.9.3)
# Requirement already satisfied: protobuf<8,>=3.20 in C:\Users\Surface Laptop 4\AppData\Local\Programs\Python\Python314\Lib\site-packages (from streamlit) (7.35.1)
# Requirement already satisfied: pyarrow>=7.0 in C:\Users\Surface Laptop 4\AppData\Local\Programs\Python\Python314\Lib\site-packages (from streamlit) (24.0.0)
# Requirement already satisfied: requests<3,>=2.27 in C:\Users\Surface Laptop 4\AppData\Local\Programs\Python\Python314\Lib\site-packages (from streamlit) (2.34.2)
# Requirement already satisfied: tenacity<10,>=8.1.0 in C:\Users\Surface Laptop 4\AppData\Local\Programs\Python\Python314\Lib\site-packages (from streamlit) (9.1.4)
# Requirement already satisfied: toml<2,>=0.10.1 in C:\Users\Surface Laptop 4\AppData\Local\Programs\Python\Python314\Lib\site-packages (from streamlit) (0.10.2)
# Requirement already satisfied: typing-extensions<5,>=4.10.0 in C:\Users\Surface Laptop 4\AppData\Local\Programs\Python\Python314\Lib\site-packages (from streamlit) (4.16.0)
# Requirement already satisfied: starlette>=0.40.0 in C:\Users\Surface Laptop 4\AppData\Local\Programs\Python\Python314\Lib\site-packages (from streamlit) (1.3.1)
# Requirement already satisfied: uvicorn>=0.30.0 in C:\Users\Surface Laptop 4\AppData\Local\Programs\Python\Python314\Lib\site-packages (from streamlit) (0.50.0)
# Requirement already satisfied: httptools>=0.6.3 in C:\Users\Surface Laptop 4\AppData\Local\Programs\Python\Python314\Lib\site-packages (from streamlit) (0.8.0)
# Requirement already satisfied: anyio>=4.0.0 in C:\Users\Surface Laptop 4\AppData\Local\Programs\Python\Python314\Lib\site-packages (from streamlit) (4.14.1)
# Requirement already satisfied: python-multipart>=0.0.10 in C:\Users\Surface Laptop 4\AppData\Local\Programs\Python\Python314\Lib\site-packages (from streamlit) (0.0.32)
# Requirement already satisfied: websockets>=12.0.0 in C:\Users\Surface Laptop 4\AppData\Local\Programs\Python\Python314\Lib\site-packages (from streamlit) (16.0)
# Requirement already satisfied: itsdangerous>=2.1.2 in C:\Users\Surface Laptop 4\AppData\Local\Programs\Python\Python314\Lib\site-packages (from streamlit) (2.2.0)
# Requirement already satisfied: watchdog<7,>=2.1.5 in C:\Users\Surface Laptop 4\AppData\Local\Programs\Python\Python314\Lib\site-packages (from streamlit) (6.0.0)
# Requirement already satisfied: jinja2 in C:\Users\Surface Laptop 4\AppData\Local\Programs\Python\Python314\Lib\site-packages (from altair!=5.4.0,!=5.4.1,<7,>=4.0->streamlit) (3.1.6)
# Requirement already satisfied: jsonschema>=3.0 in C:\Users\Surface Laptop 4\AppData\Local\Programs\Python\Python314\Lib\site-packages (from altair!=5.4.0,!=5.4.1,<7,>=4.0->streamlit) (4.26.0)
# Requirement already satisfied: narwhals>=2.4.0 in C:\Users\Surface Laptop 4\AppData\Local\Programs\Python\Python314\Lib\site-packages (from altair!=5.4.0,!=5.4.1,<7,>=4.0->streamlit) (2.23.0)
# Requirement already satisfied: colorama in C:\Users\Surface Laptop 4\AppData\Roaming\Python\Python314\site-packages (from click<9,>=7.0->streamlit) (0.4.6)
# Requirement already satisfied: gitdb<5,>=4.0.1 in C:\Users\Surface Laptop 4\AppData\Local\Programs\Python\Python314\Lib\site-packages (from gitpython!=3.1.19,<4,>=3.0.7->streamlit) (4.0.12)
# Requirement already satisfied: smmap<6,>=3.0.1 in C:\Users\Surface Laptop 4\AppData\Local\Programs\Python\Python314\Lib\site-packages (from gitdb<5,>=4.0.1->gitpython!=3.1.19,<4,>=3.0.7->streamlit) (5.0.3)
# Requirement already satisfied: python-dateutil>=2.8.2 in C:\Users\Surface Laptop 4\AppData\Local\Programs\Python\Python314\Lib\site-packages (from pandas<4,>=1.4.0->streamlit) (2.9.0.post0)
# Requirement already satisfied: tzdata in C:\Users\Surface Laptop 4\AppData\Local\Programs\Python\Python314\Lib\site-packages (from pandas<4,>=1.4.0->streamlit) (2026.2)
# Requirement already satisfied: charset_normalizer<4,>=2 in C:\Users\Surface Laptop 4\AppData\Local\Programs\Python\Python314\Lib\site-packages (from requests<3,>=2.27->streamlit) (3.4.7)
# Requirement already satisfied: idna<4,>=2.5 in C:\Users\Surface Laptop 4\AppData\Local\Programs\Python\Python314\Lib\site-packages (from requests<3,>=2.27->streamlit) (3.18)
# Requirement already satisfied: urllib3<3,>=1.26 in C:\Users\Surface Laptop 4\AppData\Local\Programs\Python\Python314\Lib\site-packages (from requests<3,>=2.27->streamlit) (2.7.0)
# Requirement already satisfied: certifi>=2023.5.7 in C:\Users\Surface Laptop 4\AppData\Local\Programs\Python\Python314\Lib\site-packages (from requests<3,>=2.27->streamlit) (2026.6.17)
# Requirement already satisfied: MarkupSafe>=2.0 in C:\Users\Surface Laptop 4\AppData\Local\Programs\Python\Python314\Lib\site-packages (from jinja2->altair!=5.4.0,!=5.4.1,<7,>=4.0->streamlit) (3.0.3)
# Requirement already satisfied: attrs>=22.2.0 in C:\Users\Surface Laptop 4\AppData\Local\Programs\Python\Python314\Lib\site-packages (from jsonschema>=3.0->altair!=5.4.0,!=5.4.1,<7,>=4.0->streamlit) (26.1.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in C:\Users\Surface Laptop 4\AppData\Local\Programs\Python\Python314\Lib\site-packages (from jsonschema>=3.0->altair!=5.4.0,!=5.4.1,<7,>=4.0->streamlit) (2025.9.1)
# Requirement already satisfied: referencing>=0.28.4 in C:\Users\Surface Laptop 4\AppData\Local\Programs\Python\Python314\Lib\site-packages (from jsonschema>=3.0->altair!=5.4.0,!=5.4.1,<7,>=4.0->streamlit) (0.37.0)
# Requirement already satisfied: rpds-py>=0.25.0 in C:\Users\Surface Laptop 4\AppData\Local\Programs\Python\Python314\Lib\site-packages (from jsonschema>=3.0->altair!=5.4.0,!=5.4.1,<7,>=4.0->streamlit) (2026.6.3)
# Requirement already satisfied: six>=1.5 in C:\Users\Surface Laptop 4\AppData\Local\Programs\Python\Python314\Lib\site-packages (from python-dateutil>=2.8.2->pandas<4,>=1.4.0->streamlit) (1.17.0)
# Requirement already satisfied: h11>=0.8 in C:\Users\Surface Laptop 4\AppData\Local\Programs\Python\Python314\Lib\site-packages (from uvicorn>=0.30.0->streamlit) (0.16.0)

# %%
import streamlit as st

st.title("First Streamlit app")

st.write("Helloww. I am here to build apps!")

name = st.text_input("What is your name?")
age = st.slider("How old are you?", 1, 100, 25)
if name:
    st.write(f"Nice to meet you {name}")
# Out:
# 2026-07-07 12:14:37.769 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-07-07 12:14:37.770 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-07-07 12:14:37.771 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-07-07 12:14:37.772 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-07-07 12:14:37.772 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-07-07 12:14:37.773 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-07-07 12:14:37.774 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-07-07 12:14:37.775 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-07-07 12:14:37.775 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-07-07 12:14:37.776 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-07-07 12:14:37.776 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-07-07 12:14:37.777 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-07-07 12:14:37.778 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-07-07 12:14:37.778 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-07-07 12:14:37.779 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-07-07 12:14:37.780 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-07-07 12:14:37.781 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-07-07 12:14:37.782 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-07-07 12:14:37.783 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
