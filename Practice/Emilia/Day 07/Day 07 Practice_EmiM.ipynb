# %%
# Tkinter --- Built-in python - no new installation is needed
import tkinter as tk # aliases 

# create a blank window
window = tk.Tk() # class is used to create the main application window
window.title("My First Tkinter GUI App")
window.geometry("270x360") # sets the window size

# created some text, to attach with the window
greeting = tk.Label(window, 
                    text = "Hello User Interface!",
                    font=("Helvetica", 16, "bold"), # font, frontsize, style
                    fg= "white", # foreground
                    bg = "blue" # background
                    )

# packing - take the greeting, and put it on the window
greeting.pack()
greeting = tk.Label(window, text = "Hello User Interface!", font=("Helvetica", 32, "bold"))
greeting.pack()
greeting = tk.Label(window, text = "Hello Use Interface!")


# action
def button_fool():
    print("You clicked Fool me, you FOOL!")


# Button
action_button = tk.Button(window,
                          text= "Fool me",
                          command= "button_fool",
                          font=("Helvetica", 16, "bold"),
                          fg= "white", # foreground
                          bg= "blue", # background, 
                          width= 15,
                          height= 3,
                          relief= "raised", # flat, raised, sunken, solid, ridge, groove
                          cursor= "hand2" # change the mouse to a hand 
                        )
action_button.pack(padx= 0)


# action
def button_clicked():
    print("ALL HAIL THE BUTTON CLIKER!!!!")


# Button
action_button = tk.Button(window,
                          text= "Praise me",
                          command= "button_praise", 
                          font=("Helvetica", 32, "bold"), # font, fontsize, style
                          fg= "white", # foreground
                          bg= "blue", # background,
                          width= 15,
                          height= 3,
                          relief= "raised", # flat, raised, sunken, solid, ridge, groove
                          cursor= "hand2" # change the mouse to a hand
                          )

action_button.pack(pady= 20)


# Keeps the window open
window.mainloop()

# %%
### Let's create a calculator

# %%
window = tk.Tk() # create a window
window.title("Calculatior by Idrees") # window title
window.geometry("500x500") # window size - width x height


# First input
label1 = tk.Label(window, text ="Enter first Number", font=("Helvetica", 12))
label1.pack()

input1 = tk.Entry(window)
input1.pack(pady=10)

# Second input
label2 = tk.Label(window, text ="Enter second Number", font=("Helvetica", 12))
label2.pack()

input2 = tk.Entry(window)
input2.pack(pady = 10)

# function 
def calculate():
    try:
        num1 = float(input1.get())
        num2 = float(input2.get())

        add = num1 + num2
        sub = num1 - num2
        mul = num1 * num2
        div = num1 / num2

        output_label.config(text= f"Addition: {add}\nSubtraction: {sub}")

    except Exception as e:
        output_label.config(text= "Whoa, there is an error: {e}", justify = 'left')


# Calculate
calculate_button = tk.Button(window, text= "Calculate",
                          command= "button_praise", 
                          font=("Helvetica", 16, "bold"), # font, fontsize, style
                          width= 8,
                          height= 2,
                          relief= "raised", # flat, raised, sunken, solid, ridge, groove
                          cursor= "hand2" # change the mouse to a hand
                          )
calculate_button.pack(pady= 20)

# Output Label
output_label = tk.Label(window, text = "RESULTS", font=("Helvetica", 12),fg = "white", bg = "purple", justify= 'left')
output_label.pack()


 
window.mainloop()

# %% [markdown]
# ## Gradio
# -

# %% [markdown]
# # APIs
# - as a data scientist it is very important that you understand your sources of data
# - SOURCE of DATA
#     - something that can give data
#     - examples are"
#         - files like .csv fike, or . sql fike
#         - documents have tables
#         - .xsls files
#     - FILES
#     - DATABASES
#     - APIs
#
# - API - Application Programming Interface
# - are a set of Rules or protocols, that allow software to share data or interact
# -
#
# - Analogy
#
# Restaurant (Food) ----------- waiter ---------- User
# website --------- API  ---------->  User

# %% [markdown]
# #### Example of a Real-World API:
#
# Let’s say you want to get **current weather** data for your location. You can use a weather service **API** like **OpenWeatherMap** to get this information. You send a request with your location (just like ordering food), and the API sends back the weather data for that location (like receiving your meal).
#
# Here’s what happens in the background:
# 1. You **send a request** to the weather API with your location.
# 2. The API communicates with a weather database.
# 3. The API **sends back data** (in JSON format) with details like temperature, humidity, and forecast.
#
#
# OpenWeatherMap API usage:
# 1. sign up to the platform
# 2. gives you a profile
# 3. create an API key ( is a treasure???)
#
# - Free platform - it allows a certain number of free requests per hour
#     - one might actually buy the usage limits

# %% [markdown]
# ### how does python talk to the internet
# - DOG

# %%
pip install requests
# Out:
# ...
#    ---------------------------------------- 0.0/7.2 MB ? eta -:--:--
#    --------------- ------------------------ 2.9/7.2 MB 24.6 MB/s eta 0:00:01
#    ---------------------------------------- 7.2/7.2 MB 23.0 MB/s  0:00:00
# ...
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 26.1.1 -> 26.1.2
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import requests # package ther help in sending requests to a server

# creat an API endpoint to fetch something
url = "http://dog.ceo/api/breeds/image/random"

# %%
response = requests.get(url)

# response code - 200 means successful connection
# response code - 404 means Not Found

# %%
response.status_code # status code of response

data = response.json()
# json is a javascrip object notation --- this is used for data -- stores in key value pairs
#

# %%
dog_url = data['message']
dog_url
# Out:
# 'https://images.dog.ceo/breeds/hound-plott/hhh-23456.jpg'

# %%
response = request.get(url)
data = response.json()
dog_url = data['message']
dog_url
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[49], line 1
# ----> 1 response = request.get(url)
#       2 data = response.json()
#       3 dog_url = data['message']
#       4 dog_url
#
# NameError: name 'request' is not defined

# %% [markdown]
# ### how does python talk to the internet
# - DOG

# %%
# pip install requests Pillow

# %%
import requests

dog_url = data['message']
dog_url
# Out:
# 'https://images.dog.ceo/breeds/hound-plott/hhh-23456.jpg'

# %%
import requests # package that helps in sending requests to a server

# %%
# create an API endpoint to fetch something
url = "https://dog.ceo/api/breeds/image/random"

# %%
response = requests.get(url)
print(response)

# response code - 200 means successful connection
# response code - 404 means Not Found

# %% [markdown]
# The requests library uses the Response class to handle the response data from the server.
# - Common HTTP Status Codes:
#
#     - 200: OK – The request was successful.
#     - 404: Not Found – The server could not find the requested page or resource.
#     - 500: Internal Server Error – There was an error on the server while processing the request.

# %% [markdown]
# ## 08.06.2026 Class

# %% [markdown]
# JSON - Javascript Object Notation
# - a standard, lightweight text format used to exchange data
# - mostly over the internet
# - used extensively in APIs
# - Almost every programming language has tools to read and write json type text
# -

# %%
# All code at once

import requests

url = "https://dog.ceo/api/breeds/image/random"
response = requests.get(url)
data = response.json()
dog_url =data['message']
dog_url

# %%
def fetch_img():
    url = "https://dog.ceo/api/breeds/image/random"
    response = requests.get(url)
    data = response.json()
    dog_url =data['message']
    
    return dog_url

# %%
import requests
url = "https://dog.ceo/api/breeds/image/random"
response = requests.get(url)
data = response.json()
dog_url =data['message']

# save the image in our workspace
# in case of an image, we need to use binary
with open("dog_image.jpg", "wb") as f:
        f.write(requests.get(dog_url).content) # .content gets the rw binary

# %%
import requests

random_user_url ="https://randomuser.me/api/"

data = requests.get(random_user_url).json()

title_name = data['results'][0]['name']['first']
first_name = data['results'][0]['name']['first']
last_name = data['results'][0]['name']['last']

name = f"{title_name} {first_name} {last_name}"
print(name)

# %%
title_name = data['results'][0]['name']['first']
title_name

first_name = data['results'][0]['name']['first']
first_name

last_name = data['results'][0]['name']['last']
last_name

# %%
import requests

random_user_url ="https://randomuser.me/api/"

data = requests.get(random_user_url).json()

name = "mr. Ross Daniels"
residence = "wollongong australia" # city and country
email = "ross.daniels@example.com"

print(residence)

# %%
city = data['results'][0]['location']['city']
country = data['results'][0]['location']['country']
email = data['results'][0]['email']

# %%
# List of APIs that fetch random data

random_user_url = "https://randomuser.me/api/"
# Fetches random user profile data (name, email, phone, address)

#random_activity_url = "https://www.boredapi.com/api/activity"
# Fetches a random activity suggestion with type and participants

random_quote_url = "https://api.quotable.io/random"
# Fetches a random quote with author and content

random_cat_url = "https://api.thecatapi.com/v1/images/search"
# Fetches random cat image URL and breed information

random_joke_url = "https://official-joke-api.appspot.com/random_joke"
# Fetches a random joke with setup and punchline

random_pokemon_url = "https://pokeapi.co/api/v2/pokemon/random"
# Fetches random Pokémon data with stats, abilities, and sprites

random_advice_url = "https://api.adviceslip.com/advice"
# Fetches random life advice slip with advice text

random_university_url = "http://universities.hipolabs.com/search?country=US"
# Fetches list of random universities with names and domains

# %% [markdown]
# Now it's your turn!
# ## Weather App Project
# ### Fetch Weather Data Using OpenWeatherMap AP and create a dataset (Advanced - Optional)
#
#
# - **Objective:**
#   You will create a JSON file containing weather data for multiple cities over a period of 15 minutes. This task will help you practice your skills in making API calls, handling JSON responses, and converting data into a DataFrame.
#
# - **Cities to Include:**
#   - New York, USA
#   - London, UK
#   - Tokyo, Japan
#   - Sydney, Australia
#   - Paris, France

# %% [markdown]
# '''python
# API
# |
# |
# |
# Json
# |
# |
# Table
# Table ---  Pandas ---- Analysis
# Table --- Maplotlib ----
