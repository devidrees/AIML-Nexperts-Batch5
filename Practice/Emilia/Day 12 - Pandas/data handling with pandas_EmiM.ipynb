# %% [markdown]
# Working with DataFrames
# -

# %%
import pandas as pd

# %%
df = pd.read_csv("employee.csv")
display(df)
# Out:
#       Name   Department  Salary  Experience
# 0    Alice  Engineering   75000           3
# 1      Bob    Marketing   65000           5
# 2  Charlie  Engineering   80000           7
# 3    Diana           HR   60000           2
# 4      Eve    Marketing   70000           4

# %% [markdown]
# ## Column Selection in Pandas
# - df["column_name"]
# - df.Column_name
# - a single column will exist as a series object'
#
# - df[data] this indexing method will take a single argument --- a `string` or a `list`
#     - what if we need multiple columns

# %%
# acessing columns in the dataframe
# access columns by --- Name
df['Name']
df.Name # only one column


columns = ["Name","Salary",	"Experience"]
df[columns]

# subset of dataframe
df_salary = df[["Salary",	"Experience"]]
display(df_salary)

#df["Name","Salary"] # will not work
# Out:
#    Salary  Experience
# 0   75000           3
# 1   65000           5
# 2   80000           7
# 3   60000           2
# 4   70000           4

# %%
display(df)
# Out:
#       Name   Department  Salary  Experience
# 0    Alice  Engineering   75000           3
# 1      Bob    Marketing   65000           5
# 2  Charlie  Engineering   80000           7
# 3    Diana           HR   60000           2
# 4      Eve    Marketing   70000           4

# %% [markdown]
# ### Selection using the location or Labels
#
# integer Location --- .iloc[]
# - df.iloc[row index] 3 access rows
# - df.iloc[row_index_slice] # [start: end : stepsize]
#
# INDEXING ----
# - df.iloc[row_slice, column_slice]
# -

# %%
df.iloc[0]
display(df)
# Out:
#       Name   Department  Salary  Experience
# 0    Alice  Engineering   75000           3
# 1      Bob    Marketing   65000           5
# 2  Charlie  Engineering   80000           7
# 3    Diana           HR   60000           2
# 4      Eve    Marketing   70000           4

# %%
df.iloc[0] # first row as a series object

df.iloc[-1] # last row

df.iloc[1:3] # rows from 1 upto 3

df.iloc[1:4:2] # in steps of 2

# ---- indexing works

df.iloc[:4, 1:3] #first 4 rows, 

df.iloc[[0,2,3], [0,2,3]] # you can access the rows, columns by number, but
# if out of index, error will be thrown
# errors are not thrown if you are accessing using slices
# Out:
#       Name  Salary  Experience
# 0    Alice   75000           3
# 2  Charlie   80000           7
# 3    Diana   60000           2

# %%
# i want the data of the last two entries, for department and experience
df.iloc[-2:,[1,3]]
# Out:
#   Department  Experience
# 3         HR           2
# 4  Marketing           4

# %% [markdown]
# ## Label - .loc[]
#
# - focuses on labels
# - df.loc[0:3] # targets the names of these rows
# - Which are the indexes

# %%
# 
ind = ['a','b','c','d','e']
df = pd.read_csv("employee.csv")
df['index'] = ind

df = df.set_index('index')
display(df)
# -----
df.index = ['a','b','c','d','e']
display(df)
# Out:
#           Name   Department  Salary  Experience
# index
# a        Alice  Engineering   75000           3
# b          Bob    Marketing   65000           5
# c      Charlie  Engineering   80000           7
# d        Diana           HR   60000           2
# e          Eve    Marketing   70000           4
#       Name   Department  Salary  Experience
# a    Alice  Engineering   75000           3
# b      Bob    Marketing   65000           5
# c  Charlie  Engineering   80000           7
# d    Diana           HR   60000           2
# e      Eve    Marketing   70000           4

# %%
df.loc[0] # row
df.loc[0:3] # slice of rows

# df.loc[0:3, 0:3] # throws an error

df.loc[0:3, ['Department', 'Experience']]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File c:\Users\user\AppData\Local\Programs\Python\Python314\Lib\site-packages\pandas\core\indexes\base.py:3641, in Index.get_loc(self, key)
#    3640 try:
# -> 3641     return self._engine.get_loc(casted_key)
#    3642 except KeyError as err:
#
# File pandas/_libs/index.pyx:168, in pandas._libs.index.IndexEngine.get_loc()
# --> 168 'Could not get source, probably due dynamically evaluated source code.'
#
# File pandas/_libs/index.pyx:176, in pandas._libs.index.IndexEngine.get_loc()
# --> 176 'Could not get source, probably due dynamically evaluated source code.'
#
# File pandas/_libs/index.pyx:583, in pandas._libs.index.StringObjectEngine._check_type()
# --> 583 'Could not get source, probably due dynamically evaluated source code.'
#
# KeyError: 0
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[39], line 1
# ----> 1 df.loc[0] # row
#       2 df.loc[0:3] # slice of rows
#       3
#       4 # df.loc[0:3, 0:3] # throws an error
#
# File c:\Users\user\AppData\Local\Programs\Python\Python314\Lib\site-packages\pandas\core\indexing.py:1207, in _LocationIndexer.__getitem__(self, key)
#    1205 maybe_callable = com.apply_if_callable(key, self.obj)
#    1206 maybe_callable = self._raise_callable_usage(key, maybe_callable)
# -> 1207 return self._getitem_axis(maybe_callable, axis=axis)
#
# File c:\Users\user\AppData\Local\Programs\Python\Python314\Lib\site-packages\pandas\core\indexing.py:1449, in _LocIndexer._getitem_axis(self, key, axis)
#    1447 # fall thru to straight lookup
#    1448 self._validate_key(key, axis)
# -> 1449 return self._get_label(key, axis=axis)
#
# File c:\Users\user\AppData\Local\Programs\Python\Python314\Lib\site-packages\pandas\core\indexing.py:1399, in _LocIndexer._get_label(self, label, axis)
#    1397 def _get_label(self, label, axis: AxisInt):
#    1398     # GH#5567 this will fail if the label is not present in the axis.
# -> 1399     return self.obj.xs(label, axis=axis)
#
# File c:\Users\user\AppData\Local\Programs\Python\Python314\Lib\site-packages\pandas\core\generic.py:4253, in NDFrame.xs(self, key, axis, level, drop_level)
#    4249                     new_index = index[loc : loc + 1]
#    4250                 else:
#    4251                     new_index = index[loc]
#    4252         else:
# -> 4253             loc = index.get_loc(key)
#    4254
#    4255             if isinstance(loc, np.ndarray):
#    4256                 if loc.dtype == np.bool_:
#
# File c:\Users\user\AppData\Local\Programs\Python\Python314\Lib\site-packages\pandas\core\indexes\base.py:3648, in Index.get_loc(self, key)
#    3643     if isinstance(casted_key, slice) or (
#    3644         isinstance(casted_key, abc.Iterable)
#    3645         and any(isinstance(x, slice) for x in casted_key)
#    3646     ):
#    3647         raise InvalidIndexError(key) from err
# -> 3648     raise KeyError(key) from err
#    3649 except TypeError:
#    3650     # If we have a listlike key, _check_indexing_error will raise
#    3651     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3652     #  the TypeError.
#    3653     self._check_indexing_error(key)
#
# KeyError: 0

# %%
df.loc['a':'d', 'Department':'Experience':2]
# Out:
#     Department  Experience
# a  Engineering           3
# b    Marketing           5
# c  Engineering           7
# d           HR           2

# %%
df = pd.read_csv("employee.csv")

df.index = ("a","b","c","d","e")
 
df
# Out:
#       Name   Department  Salary  Experience
# a    Alice  Engineering   75000           3
# b      Bob    Marketing   65000           5
# c  Charlie  Engineering   80000           7
# d    Diana           HR   60000           2
# e      Eve    Marketing   70000           4

# %%
df.index
df.columns
# Out:
# Index(['Name', 'Department', 'Salary', 'Experience'], dtype='str')

# %%
df.iloc[[0,2,3], [0,2,4]]   # you can access the rows, columns by number, but 
# it out of index, error will be thrown

# %%
# EXCERCISE
# 
# i want the data of the last two entries, for department and experience

df.iloc[-2,[1,3]]
# Out:
# Department    HR
# Experience     2
# Name: d, dtype: object

# %% [markdown]
# - Label - ,loc[]
# - focuses on labels
# - df.loc[0:3]   # targets the names of these rows
# - which are the indexes
# -

# %%
df.loc[0]   # row
df.loc[0:3] # slice of rows

df.loc[0:3, 0:3]

# %%
#
ind = ['a', 'b', 'c', 'd', 'e']
df = pd.read_csv("employee.csv")
df['index'] = ind

df.set_index('index')
display(df)

# %%
# Optional_Luqman

df = pd.read_csv("employee.csv")
df.index = ("a","b","c","d","e")
 
df
# Out:
#       Name   Department  Salary  Experience
# a    Alice  Engineering   75000           3
# b      Bob    Marketing   65000           5
# c  Charlie  Engineering   80000           7
# d    Diana           HR   60000           2
# e      Eve    Marketing   70000           4

# %% [markdown]
# Adding and Modifiying Columns

# %%
df.iloc[0:3, 0:2]
# Out:
#       Name   Department
# a    Alice  Engineering
# b      Bob    Marketing
# c  Charlie  Engineering

# %%
# adding a column
# access a column that does does not exist
df['email'] = {}
df

# df['email'] = []
df
# Out:
#       Name   Department  Salary  Experience              email
# a    Alice  Engineering   75000           3     alice@gmailcom
# b      Bob    Marketing   65000           5      bob@gmail.com
# c  Charlie  Engineering   80000           7  charlie@gmail.com
# d    Diana           HR   60000           2    diana@gmail.com
# e      Eve    Marketing   70000           4      eve@gmail.com

# %%
df['email'] = ['alice@gmailcom', 'bob@gmail.com', 'charlie@gmail.com', 'diana@gmail.com', 'eve@gmail.com']
df
# Out:
#       Name   Department  Salary  Experience              email
# a    Alice  Engineering   75000           3     alice@gmailcom
# b      Bob    Marketing   65000           5      bob@gmail.com
# c  Charlie  Engineering   80000           7  charlie@gmail.com
# d    Diana           HR   60000           2    diana@gmail.com
# e      Eve    Marketing   70000           4      eve@gmail.com

# %%
# modify
df['Department']['d'] = 'Crime Analytics'
df
# Out:
# C:\Users\user\AppData\Local\Temp\ipykernel_24732\4083700284.py:2: ChainedAssignmentError: A value is being set on a copy of a DataFrame or Series through chained assignment.
# Such chained assignment never works to update the original DataFrame or Series, because the intermediate object on which we are setting values always behaves as a copy (due to Copy-on-Write).
#
# Try using '.loc[row_indexer, col_indexer] = value' instead, to perform the assignment in a single step.
#
# See the documentation for a more detailed explanation: https://pandas.pydata.org/pandas-docs/stable/user_guide/copy_on_write.html#chained-assignment
#   df['Department']['d'] = 'Crime Analytics'
#       Name   Department  Salary  Experience
# a    Alice  Engineering   75000           3
# b      Bob    Marketing   65000           5
# c  Charlie  Engineering   80000           7
# d    Diana           HR   60000           2
# e      Eve    Marketing   70000           4

# %%
list(df['Department'])

df['Department'] = ['Engineering', 'Marketing', 'Physics', 'HR', 'Marketing']

# use modify all elements in one go
df.Salary = df.Salary/1000  # Scaling operation
# took the column and scled it down

df.Experience = df.Experience +1

# %%
# modifying a value
# df['Department']['d'] = 'Crime Analytics'


df.loc['d','Department'] = 'Crime Analytics'
df
# Out:
#       Name       Department    Salary  Experience  (Department, d)  \
# a    Alice      Engineering  0.000075           6  Crime Analytics
# b      Bob        Marketing  0.000065           8  Crime Analytics
# c  Charlie          Physics  0.000080          10  Crime Analytics
# d    Diana  Crime Analytics  0.000060           5  Crime Analytics
# e      Eve        Marketing  0.000070           7  Crime Analytics
#
#    (d, Department)
# a  Crime Analytics
# b  Crime Analytics
# c  Crime Analytics
# d  Crime Analytics
# e  Crime Analytics

# %% [markdown]
# ### EDA (Exploratory Data Analaysis) with Pandas
# - some methods that we can run on dataframes
# - df.head()     - give you the first 5 elements
#     - an arguments of  will give you first  emlements
# - df.tail()     -
# - df.sample()
#
# - Basic attributes of a dataframe
# - df.shape
# - df.size       - how many elements there are
# - df.ndim       - will tell you the number of axes there are in the df ---- generally just 2
# - `df.dtypes`   -
#
#
# - df.info()
# - df.describe()

# %%
df.head(10)
df.tail()
df.sample()

df.shape
df.size
df.dtypes


df.info()
df.describe()
# Out:
# <class 'pandas.DataFrame'>
# Index: 5 entries, a to e
# Data columns (total 6 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Name             5 non-null      str
#  1   Department       5 non-null      str
#  2   Salary           5 non-null      float64
#  3   Experience       5 non-null      int64
#  4   (Department, d)  5 non-null      str
#  5   (d, Department)  5 non-null      str
# dtypes: float64(1), int64(1), str(4)
# memory usage: 452.0+ bytes
#              Salary  Experience
# count  5.000000e+00    5.000000
# mean   7.000000e-08    8.200000
# std    7.905694e-09    1.923538
# min    6.000000e-08    6.000000
# 25%    6.500000e-08    7.000000
# 50%    7.000000e-08    8.000000
# 75%    7.500000e-08    9.000000
# max    8.000000e-08   11.000000

# %% [markdown]
# Exercise:
# - Please go to Kaggle
# - Download this dataset: https://www.kaggle.com/datasets/juhibhojani/house-price
# - perform the operations especially the EDA that we learnt about in today's class on it

# %% [markdown]
# ### Filtering

# %% [markdown]
# ### Aggregation

# %% [markdown]
# ### Grouping
