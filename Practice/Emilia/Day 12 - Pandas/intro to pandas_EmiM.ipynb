# %% [markdown]
# # Pandas
# - Python library
# - fast, powerful, flexible open source dat analysis and **manipulation** tool
# - provide Series and Dataframe objects
# - Therse objects are use to store and manipulate structured data (data in tabular form)
#
# - pandas comes from `Panel Data`
# - `Python for Data analaysis`
# - `s` refers to the series object

# %%
# pip install pandas

# %%
import pandas as pd

# %% [markdown]
# ### Core Objects
# - Series - is a one dimensional labelled array (like a single column)
#     - series = one column
# - DataFrame - a two-dimensional table made of multiple series of same index
#     - dataframe = a sheet of columns and rows

# %%
maths = pd.Series([20,30,40], name = 'math')
type(maths) # pandas.Series

print(maths)
# Out:
# 0    20
# 1    30
# 2    40
# Name: math, dtype: int64

# %%
maths = pd.Series([20,30,40], dtype ='int8', name = 'math')
type(maths) # pandas.Series

print(maths)
# Out:
# 0    20
# 1    30
# 2    40
# Name: math, dtype: int8

# %%
english = pd.Series([20,30,40])
python = pd.Series([20,55,40])
science = pd.Series([20,99,40])

# %%
pd.concat([maths, english, python, science])    # series object
# Out:
# 0    20
# 1    30
# 2    40
# 0    20
# 1    30
# 2    40
# 0    20
# 1    55
# 2    40
# 0    20
# 1    99
# 2    40
# dtype: int64

# %%
pd.concat([maths, english, python, science])    # series object

df = pd.concat([maths, english, python, science], axis = 1) 
type(df)
# Out:
# pandas.DataFrame

# %% [markdown]
# DataFrame -
# - column, rows
# -

# %%
# dataframe from dictionary of Lists  --- each list has to be of same size

data = {
    "students":["Nomie", "Idrees", "Radia"],
    "Maths":[85, 95, 90],
    "English":[75, 85, 80],
}

df = pd.DataFrame(data)
print(df)
display(df)
df
# Out:
#   students  Maths  English
# 0    Nomie     85       75
# 1   Idrees     95       85
# 2    Radia     90       80
#   students  Maths  English
# 0    Nomie     85       75
# 1   Idrees     95       85
# 2    Radia     90       80
#   students  Maths  English
# 0    Nomie     85       75
# 1   Idrees     95       85
# 2    Radia     90       80

# %%
# dataframe from List of Dictionaries --- each dictionary can be of different size
# we can miss elements --- those elements will appear as NaN values

data = [
    {'Name': 'Alice', 'Age': 25, 'City': 'New York'},
    {'Name': 'Bob', 'Age': 30, 'City': 'London'},
    {'Name': 'Charlie', 'Age': 35}
]

df = pd.DataFrame(data)
df
# Out:
#       Name  Age      City
# 0    Alice   25  New York
# 1      Bob   30    London
# 2  Charlie   35       NaN

# %% [markdown]
# - NaN values
#     - Not a Number
#     - aka Missing Values

# %%
# dataframe from 2D arrays
data = [
    ['Alice', 25, 'New York'],
    ['Bob', 30, 'London'],
    ['Charlie', 35, 'Paris']
]

# We must explicitly define columns here
df = pd.DataFrame(data, columns=['Name', 'Age', 'City'], )
print(df)
# Out:
#       Name  Age      City
# 0    Alice   25  New York
# 1      Bob   30    London
# 2  Charlie   35     Paris

# %% [markdown]
# Series has:
# - Index
# - Name
#
# DataFrame will have:
# - Header - is the names of columns
#     - pd.`DataFrame`(file, `columns` = ["col1", "col2", "col3"])
# - Index -
#     - pd.DataFrame(file, `columns` - ["col1", "col2", "col3"], index = [1,2,3])
#     - index_col = "column name" ===> argument we can pass as well
#     - df.set_index("column name")

# %% [markdown]
# # set index manually
# data = [
#     {'Name': 'Alice', 'Age': 25, 'City': 'New York'},
#     {'Name': 'Bob', 'Age': 30, 'City': 'London'},
#     {'Name': 'Charlie', 'Age': 35, 'City': 'Paris'}
# ]
#
# df = pd.DataFrame(data)
# print(df)

# %%
# DataFrame from previous excercise

import numpy as np
np.random.seed(42)

# %% [markdown]
# Reading from and writing to a CSV files
# - pd.read_csv()

# %%
# DataFrames from Files
 
# From a CSV file
df_csv = pd.read_csv('my_data.csv')
 
# From an Excel file
df_excel = pd.read_excel('my_data.xlsx')
 
# From a JSON file or API response
df_json = pd.read_json('my_data.json')

# %%
# Let's create a sample CSV file first, then read it
sample_data = """Name,Department,Salary,Experience
Alice,Engineering,75000,3
Bob,Marketing,65000,5
Charlie,Engineering,80000,7
Diana,HR,60000,2
Eve,Marketing,70000,4"""

with open("employee.csv", 'w') as f:
    f.write(sample_data)

# %%
df = pd.read_csv("employee.csv")
df
# Out:
#       Name   Department  Salary  Experience
# 0    Alice  Engineering   75000           3
# 1      Bob    Marketing   65000           5
# 2  Charlie  Engineering   80000           7
# 3    Diana           HR   60000           2
# 4      Eve    Marketing   70000           4

# %%
# Dataframe for the Previou Scenario Exercise

import numpy as np
np.random.seed(42)
 
#2.
results = np.random.randint(0,101, (10,3))
print("--- Results ---")
print(results)

df_results = pd.DataFrame(results, columns = ["maths", "english","science"])

df_results.to_csv("student_marks.csv", index = False) # it excludes the index
# Out:
# --- Results ---
# [[51 92 14]
#  [71 60 20]
#  [82 86 74]
#  [74 87 99]
#  [23  2 21]
#  [52  1 87]
#  [29 37  1]
#  [63 59 20]
#  [32 75 57]
#  [21 88 48]]

# %%
df_results
# Out:
#    maths  english  science
# 0     51       92       14
# 1     71       60       20
# 2     82       86       74
# 3     74       87       99
# 4     23        2       21
# 5     52        1       87
# 6     29       37        1
# 7     63       59       20
# 8     32       75       57
# 9     21       88       48

# %% [markdown]
# Mini-Activity:
#
# 1. Create a pd.series with 5 temperature value and print it.
#
# 2. Create a pd.DataFrame with column "City" and "Temperature" for 3 cities.
#
# 3. Check the type() of each object you created.
#
# 4. Add a name to your Series and print it again.

# %%
maths = pd.Series([20,30,40], dtype ='int8', name = 'math')
type(maths) # pandas.Series

# %%
import pandas as pd

#1.
temp = ([25, 5, -3, 28, 17])

#2.
data = {
    "temp": [25, 5, -3],
    "city": ["KL", "Sabah", "Alaska"],
}
df = pd.DataFrame(data)

#3.
dtype = 'int8'

#4.
display(df)
# Out:
#    temp    city
# 0    25      KL
# 1     5   Sabah
# 2    -3  Alaska

# %% [markdown]
# ### Reading

# %%
# Let's create a sample CSV file first, then read it
sample_data = """Name,Department,Salary,Experience
Alice,Engineering,75000,3
Bob,Marketing,65000,5
Charlie,Engineering,80000,7
Diana,HR,60000,2
Eve,Marketing,70000,4"""

with open("employee.csv", 'w') as f:
    f.write(sample_data)

# %%
df = pd.read_csv("employee.csv")
df
# Out:
#       Name   Department  Salary  Experience
# 0    Alice  Engineering   75000           3
# 1      Bob    Marketing   65000           5
# 2  Charlie  Engineering   80000           7
# 3    Diana           HR   60000           2
# 4      Eve    Marketing   70000           4

# %%
# From previous excercise

np.random.seed(42)
random_temp = np.random.randint(0,101,5)
temperature = pd.Series(random_temp)
display(temperature)
 
#2.
city = ["Kuala Lumpur", "Ipoh", "Putrajaya"]
random_temp = np.random.randint(0,101,3)
df = pd.DataFrame({
    "City": city,
    "Temperature": random_temp
})
 
display(df)
