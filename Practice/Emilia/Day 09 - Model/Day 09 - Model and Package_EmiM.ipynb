# %% [markdown]
# MODULES AND PACKAGES
#
# - Modularity
#     - modular design - create different modules
#     - separate modules (files) to handle separate things
#
# - Reusability
#     - use an already written piece of code again and again
#     -
#
# - we have pre-written libararies of code in python
# - we use the import keyword to bring their context into program

# %% [markdown]
# - A 'MODULE' is a single file - like a single python script
# - 'PACKAGE'
#     - a folder thar hold multiple related files together
#     - multiple module can exist in a package
#     - Libararies are packages that we can install and use
#     - we use the 'pip' package of python, to install a libabrary
#     - example:
#         'pip' install requests pillow numoy pandas
# - 'LIBRARY' are package that we can install and us
#     -Bundles **package** and **modules** together to solve a big, specific problem
#     - a libarary can hold multiple package too
#     - a giant Tool Box
#     - we use the 'pip' package of python, to install a library
#     - example:
#         - 'pip' install 'requests' 'pillow' 'numpy' 'pandas'
#
# - Library example:
#     - 'request' - used to connect to internet
#     - 'numpy' - sued for Numbers, numerical opeartions
#     - 'pandas' - used for data analsis, deal with tabular data as well
#     -
#
# - Python, open the folder/file and let me use the tools inside
#     - impory tkinter
#     - import request

# %% [markdown]
# ##### common files in Projects or Libraries
#
# `__init__.py` ---> Dunder Files
# - the Receptionist
# - existance of this file, tells python that this is an official packages
# - i.e. its a library we can use
# - this script automatically runs when we import the package
# -
# `__main__.py`
# - the Command Center of the package
# - This is like a switch you have to turn ON
# - you execute this file, to start something
#     - example:
#         - a multi agent system - has a lot of programs
#         - you want to execute some specific functions
#         - you save those in the main, and execute the main
#         - main will execute all those functions automatically
# - main.py is a script
#     - how do we execute scripts?
#     - go to terminal
#     - go to the folder where the script exists
#     - write: `python <script name.py> `
#     - another is to download a RUNNER Extension in VS Code
#
# - In any module file, if there is a function, it will be executed when you import the module(script)
#     - what shall we do
#     - whatever program there is to run in a script, we will keep it in a code block of this:
#         - `if __name__ == "__main__":`

# %% [markdown]
# # Excercise #1_09.06.206
#
# 1. please create script file that a function inside
#     - hello() - should print a hello massage
#
# 2. Create the two folder as shown

# %%
import EmiM_lib

# %%
import test_project.greet as greeting

# we can't execute script files like this in notebooks
# test_project.greet

greeting.hello('hariz')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[10], line 6
#       2
#       3 # we can't execute script files like this in notebooks
#       4 # test_project.greet
#       5
# ----> 6 greeting.hello('hariz')
#
# AttributeError: module 'test_project.greet' has no attribute 'hello'

# %%
import test_project

# %%
def greet(name):
    print(f'Hello!!, Good Morning {name}?')
    
greet('EmiM')
# Out:
# Hello!!, Good Morning EmiM?

# %%
# EXCERCISE_Hariz answer
def greet(name):
    print(f'Hello {name} world')
 
greet('Hariz')

# %% [markdown]
# # Micro School Management System Project

# %% [markdown]
# ###  Micro School management System Project
# - Discuss:
#     - What things should be there?
#     - Requirement:
#         - Website - for school to be visibale
#         - Records:
#             - information of every peron involved : teacher, student, staff, security guards, chef, janitor
#                 - can have different role
#                     - different responsibilties
#                     - different data that is important
#         - Record updations:
#             - get records
#             - modify records
#             - delete records
#         - Data Analysis of the data we are saving in databases
#         - Adding othre code for new things that are happeing
#         - there can be much much more

# %% [markdown]
# Guidance:
# 1. Creating a folder - Package - name it properly - (camel case preferred)
# 2. Problem Scoping/satement - is where you decide what to acieve
#     - also the part the decides what not to do
#     - PS : create different classess for different roles in the school
#         - We research and find the roles exactly do and then:
#         - add as many function for those reoles as possiable
# 3. Setting up an Architecture:
#     - create a clean foledr structure
#     -

# %% [markdown]
# ##### Architecture
# ```
# SchoolManagementSystem
# |
# |---- init.py -> will run automatically, when you import the SMS package
# |---- main.py -> Entry point to the application
# |---- models.py -> model
# |---- manager.py -> View and controller

# %% [markdown]
# |----init.py -> will run
