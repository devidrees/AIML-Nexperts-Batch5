# %% [markdown]
# # Working with Notebooks
#
# Code cells - Treated as Code/ Program
#   - will execute the text you write in the python interpreter
#
# Text cells - Treated as just text
#   - will execute it as Markdown (is just formatted text)
#
# in markdown # is used for headings
# # heading 1
# ## Heading 2
# ### Sub heading
# #### Sub heading 2
# ##### Body Text 1
# ###### Body Text 2
# ###### Body Text 3
#
# You can use HTML in Markdown too
# - is the language of browsers
# - in html we have tags e.g.
#
# <h1> Something Big </h1>
# <h2> Something Big </h2>
# <h3> Something Big </h3>
# <h6> Something Texty </h6>
#
#
#
# - *italic*
# - **Bold**
# - $Latex$
# - $$Latex-Centered$$

# %% [markdown]
# # Running Python
#
# - Python Scripts - (are simply python files. Extension - *.py)
#   - We can create by directly creating a file and changing its extension
#   - Run scripts directly on PC using a Terminal (command prompt)
#   - VS Code
#
#
#
# - Python Notebooks (are notebook files. Extension - *.ipynb)
#   - need to create a notebook from a software
#   - Using Google Colab
#   - Jupyter Notebook (Online - or download Anaconda Software)
#   - Using VS Code

# %% [markdown]
# # New Section

# %% [markdown]
# ### Terminal
# - Is the place we can control computer from
# - back in the days when we had no GUI user interface, we used terminal to do everything on a computer
# - you only use commands
# - Examples:
#   > cd - change directory
#
#   > cd.. - change directory go one step back
#
#   - Ctrl + z -> closes terminal

# %%
# comment -
# These are remarks that developers use to label different lines of code
# the interpreters basically ignores and skips these lines

print("idrees") # line of code, instruction for the computer to do something
# Out:
# idrees

# %% [markdown]
# ## Clean Code
#
# - Good Developers:
#   - Good, clean, readable, understandable
#   -
#
# - writing comments in code is considered best practice
# -

# %%
# if else statements

# Voting Eligibility Calculator

age =17 # creating a variable

if age>=18: # condition
                  print("Can Vote!")
else        :
 print("What Vote?????")
# Out:
# What Vote?????

# %% [markdown]
# - In python we follow the PEP standards
# - are rules that developers follow to maintain good code
#   - examples:
#     - specify how to name the variables too
#     - 4 spaces to indent code
#     - descriptive variable names - unambigous
#
# - To clean unnecessary spaces and lines, we use code Refactor
# -

# %%
a = 17

if a >= 18:
  print("Can Vote!")
else:
  print("Cannot Vote")
# clean well formatted code

# later if a developer needs to write the same instructions eg. in C++ so that the system is fast
# they should not need to ask the code writer what they meant
# Out:
# Cannot Vote

# %%
# Declaring Variables

user_age = 17
type(user_age) # to check the type of a variable

age = "17"
type(user_age) # str - string now ---- we use double inverted quotes
# Out:
# str

# %% [markdown]
# Things about python:
# 1. Interpreted language - executed line by line
# 2. Indented Language - where the line of code starts in the editor matters
# 3. Dynamically Typed Language - you don't need to specify the type of a variable
# 4. Cross Platform Compatible
# 5. Lacks a little on speed compared to some other languages

# %% [markdown]
# # Variables in Python
#
# - variable = labeled box for a value
# - you can store any data type in this box
# - Variable is a reserved memory location
#   - python automatically determines the type of the thing you want to save, and assigns memory
#   -
#
#
# - Rules:
#   1. use proper names not abbrevations - for Readable
#   2. use snake_case
#   3. use camelCase for Functions
#   4. use lowercase letters and underscores
#   5. avoid abbrevations like - sc, r, cn
#   6. A variable name cannot start with a number

# %%
10 = 12

# %%
name = 'Idrees'
age = 17

# %%
# printing string variable

first_name = "Mohammad"
second_name = "Idrees"
last_name = "Bhat"

print(first_name, second_name, "is my name") # used comma to concatenate (Join) two strings
print(first_name + second_name + " is my name")
# Out:
# Mohammad Idrees is my name
# MohammadIdrees is my name

# %%
# formatted string literals
print(f"My name is {first_name} {second_name}")


print("My name is {} {}".format(first_name, second_name))
# Out:
# My name is Mohammad Idrees
# My name is Mohammad Idrees

# %%
# arthematic operations
10 + 3
10-3
10/3
10 * 3
10 ** 3
# Out:
# 1000

# %%
"idrees" + "5" # concatenation

# %%
# take string and add a number to it


"idrees" * 5 # only works for multiply

# We cannot add a string to a number
# Out:
# 'idreesidreesidreesidreesidrees'

# %%
x = input("enter your age")
print(x)

type(x)
# Out:
# enter your age54
# 54
# str

# %% [markdown]
# ## Type Casting
# - it means we can force one type of variable into another type
# -

# %%
# Type casting

x = 10
str_x = str(x)
float_x = float(x)

print(type(x))
print(type(str_x))
# Out:
# <class 'int'>
# <class 'str'>

# %%
# use a method called input to declare variables too
# by taking input

# BMI CALCULATOR

name = input("enter your Name:")
age = int(input("enter your age:"))
weight = int(input("enter your weight (in kg):"))
height = int(input("enter your height (in cm):")) * 0.01

bmi = weight / (height * height)

print(f"Hi {name}! Your BMI is {bmi:.2f}")
# Out:
# enter your Name:Idrees
# enter your age:30
# enter your weight (in kg):80
# enter your height (in cm):160
# Hi Idrees ! Your BMI is 31.25

# %% [markdown]
# # Data Types

# %%
# Primitive Data Types
numbers = 17 # int - integer - any whole numbers
decimal = 3.14 # float - fractions

words = 'Idrees est awesome' # string - alphabets, words, sentences - quotation marks
sentences = 'Idrees is awesome'

names = "Idrees's car. \nBut he wants a Porche 911" # use when apstrophe is needed

paragraph = '''Idrees is an awesome teacher.
His way of teaching is next level!!!
whatever you write in three quotes, comes up as is
'''


booleans = True # bool values - True or False
type(booleans)
# Out:
# bool

# %%
print(paragraph)
# Out:
# Idrees is an awesome teacher.
# His way of teaching is next level!!!
# whatever you write in three quotes, comes up as is

# %% [markdown]
# - we use \ in python for - escape sequences
#   - \n - newline
#   -

# %% [markdown]
# # Operations

# %%
# arthematic operations
10 + 3
10-3
10/3 # division
10//3 # floor division
10 % 3 # modular division --- % modulus operator
# returns the remainder
10 % 7

10 * 3
10 ** 3 # raised to power 3
10 ** 0.5 # Square root
# Out:
# 3.1622776601683795
