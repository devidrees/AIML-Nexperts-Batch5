# %% [markdown]
# ### Environments in Python

# %% [markdown]
# - In Python, environments refer to isolated **workspaces** where you can **install** and **manage** packages without affecting the global Python installation
#
# -
#
#
# - when we are building software, or projects, which version of python we use , is important
#     - say:
#         - if i write some line of code in python 3.10
#         - the same line may not work in python 3.13
#         - the developers could have removed something (deprecated) that line of code
#         - or the new update of python might have a new way of doing the same thing
#         - this is true for all kinds of packages/libraries
#
#
# - libraries get updated all the time
#     - does that mean
#         - we built somthing in 2020
#         - if libraries get updated a lot
#         - will the same package work in 2026
#
#
# - DEPENDENCIES - all the things needed to make a app/package work
#     - Every program/application/package that we create will only work if we have all the dependencies installed

# %% [markdown]
# Whenever we create a project, we must create a separate **environment** for it -
# - an environment will save all the **packages we install**
# - all the **dependencies** of the project
# - save all the **keys/secrets**
# - this environment, will not mess up my **global environment** (PC environment)
# - we experiment a lot when creating projects
# -
#
#
# - when we upload our project online, we do no keep the evironment in there

# %% [markdown]
# We have already done:
#
# pip install `requests` `pillow` `numpy`

# %% [markdown]
# - `where python` - show you where you have installed python interpreter
#
# - `pip list` - show you all the libraries you have installed
# - `py -0p` - will tell you how many version of python you have and where
# - create a new environment - `python -m venv <environment name>`
#     - .venv is a name recognized by IDEs like vscode
# - to activate environment - `.venv\scripts\activate`
# - to deactivate an environment - `deactivate`
