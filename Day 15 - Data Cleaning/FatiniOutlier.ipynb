# %%
import numpy as np
import pandas as pd

# Sample dataset of e-commerce transactions
# Create a dictionary of multiple data items
data = [
    {"ID": 1001, "Name": "Alice Smith",  "Email": "alice@example.com",        "Product": "Laptop",     "Quantity": 1,    "Price": 1200.00, "Purchase Date": "2024-09-15",   "Delivery Status": True},
    {"ID": 1002, "Name": "Bob Jones",    "Email": None,                       "Product": "Headphones", "Quantity": 2,    "Price": 150.00,  "Purchase Date": "2024-09-16",   "Delivery Status": True},
    {"ID": 1003, "Name": "Charlie John", "Email": "charlie#example.com",      "Product": "Smartphone", "Quantity": 1,    "Price": 800.00,  "Purchase Date": "16/09/2024",   "Delivery Status": True},
    {"ID": 1004, "Name": "David Lee",    "Email": "david.lee@example.com",    "Product": "Laptop",     "Quantity": 1,    "Price": 1200.00, "Purchase Date": "2024-09-17",   "Delivery Status": False},
    {"ID": 1005, "Name": "Eve Martinez", "Email": "eve.martinez@example.com", "Product": "Smartwatch", "Quantity": 3,    "Price": 600.00,    "Purchase Date": "17th Sep 2024","Delivery Status": True},
    {"ID": 1006, "Name": "Frank Wright", "Email": None,                       "Product": "Tablet",     "Quantity": 1,    "Price": 600.00,  "Purchase Date": "2024-09-18",   "Delivery Status": False},
    {"ID": 1007, "Name": "Grace Lee",    "Email": "grace.lee@example.com",    "Product": "Laptop",     "Quantity": 1,    "Price": 12000.00, "Purchase Date": "2024-09-19",   "Delivery Status": True},
    {"ID": 1008, "Name": "Hank Brown",   "Email": "hank.brown@example.com",   "Product": "Monitor",    "Quantity": 2,    "Price": 300.00,  "Purchase Date": "09/19/2024",   "Delivery Status": True},
    {"ID": 1009, "Name": "Ivy Thompson", "Email": None,                       "Product": "Keyboard",   "Quantity": 2,    "Price": 100.00,  "Purchase Date": "2024/09/20",   "Delivery Status": False},
    {"ID": 1010, "Name": "Jack Davis",   "Email": "jack@example.com",         "Product": "Mouse",      "Quantity": 5,    "Price": 50.00,   "Purchase Date": "2024-09-21",   "Delivery Status": True},
    {"ID": 1011, "Name": "Alice Smith",  "Email": "alice@example.com",        "Product": "Laptop",     "Quantity": 1,    "Price": 1200.00, "Purchase Date": "2024-09-15",   "Delivery Status": True},  # Duplicate entry
    {"ID": 1012, "Name": "Kurt Evans",   "Email": "kurt.evans@example.com",   "Product": "Smartwatch", "Quantity": 100,   "Price": 200.00,  "Purchase Date": "2024-09-22",   "Delivery Status": True},  # Outlier quantity
    {"ID": 1013, "Name": "Liam Adams",   "Email": "liam.adams@example.com",   "Product": "Headphones", "Quantity": 2,    "Price": 150.00,  "Purchase Date": "2024-09-23",   "Delivery Status": False},
    {"ID": 1014, "Name": "Mia Clark",    "Email": "mia.clark@example.com",    "Product": None,         "Quantity": 1,    "Price": 0,       "Purchase Date": "2024-09-24",   "Delivery Status": True},  # Price anomaly
    {"ID": 1015, "Name": "Nina Turner",  "Email": None,                       "Product": "Tablet",     "Quantity": 1,    "Price": 600.00,  "Purchase Date": "24-09-2024",   "Delivery Status": True},
    {"ID": 1016, "Name": "Oscar Harris", "Email": "oscar.harris@example.com", "Product": "Laptop",     "Quantity": 2,    "Price": 1200.00, "Purchase Date": "2024-09-25",   "Delivery Status": True},
    {"ID": 1017, "Name": "Paul Young",   "Email": "paulyoung",                "Product": "Monitor",    "Quantity": 2,    "Price": 300.00,  "Purchase Date": "09/25/2024",   "Delivery Status": True},
    {"ID": 1018, "Name": "Quinn Lopez",  "Email": None,                       "Product": "Smartphone", "Quantity": 1,    "Price": 800.00,  "Purchase Date": "2024-09-26",   "Delivery Status": False},
    {"ID": 1019, "Name": "Rachel Scott", "Email": "rachel.scott@example.com", "Product": "Keyboard",   "Quantity": 2,    "Price": 100.00,  "Purchase Date": "2024-09-27",   "Delivery Status": True},
    {"ID": 1020, "Name": "Steve King",   "Email": "steve.king@example.com",   "Product": "Mouse",      "Quantity": 5, "Price": 50.00,   "Purchase Date": "2024-09-28",   "Delivery Status": True},
]

# Displaying the dataset
import pandas as pd

# Convert the list of dictionaries to a DataFrame for easier visualization and manipulation
df = pd.DataFrame(data)
df.head()
# Out:
#      ID          Name                     Email     Product  Quantity   Price  \
# 0  1001   Alice Smith         alice@example.com      Laptop         1  1200.0
# 1  1002     Bob Jones                       NaN  Headphones         2   150.0
# 2  1003  Charlie John       charlie#example.com  Smartphone         1   800.0
# 3  1004     David Lee     david.lee@example.com      Laptop         1  1200.0
# 4  1005  Eve Martinez  eve.martinez@example.com  Smartwatch         3   600.0
#
#    Purchase Date  Delivery Status
# 0     2024-09-15             True
# 1     2024-09-16             True
# 2     16/09/2024             True
# 3     2024-09-17            False
# 4  17th Sep 2024             True

# %%
df2 = df.copy()

#df2['Price'] = df2['Price'].astype('float64')

min = df2['Price'].quantile(0) # min
Q1 = df2['Price'].quantile(0.25) # First Quartile
median = df2['Price'].quantile(0.50) # Second Quartile # median
Q3 = df2['Price'].quantile(0.75) # Third Quartile
max = df2['Price'].quantile(1) # max

print(f"Min: ", min)
print(f"Q1: ", Q1)
print(f"Median: ", median)
print(f"Q3: ", Q3)
print(f"Max: ", max)

IQR = Q3 - Q1

print(f"IQR: ", IQR)

# IQR method of outlier detection
lower = Q1 - IQR*1.5
upper = Q3 + IQR*1.5

print(f"Lower Price: ", lower)
print(f"Upper Price: ", upper)

# filter out the outliers
outliers = df2[(df2['Price'] < lower) | (df2['Price'] > upper)]
print(outliers)

df2 = df2[(df2['Price'] >= lower) & (df2['Price'] <= upper)].reset_index()
df2
# Out:
# Min:  0.0
# Q1:  137.5
# Median:  450.0
# Q3:  900.0
# Max:  12000.0
# IQR:  762.5
# Lower Price:  -1006.25
# Upper Price:  2043.75
#      ID       Name                  Email Product  Quantity    Price  \
# 6  1007  Grace Lee  grace.lee@example.com  Laptop         1  12000.0
#
#   Purchase Date  Delivery Status
# 6    2024-09-19             True
#     index    ID          Name                     Email     Product  Quantity  \
# 0       0  1001   Alice Smith         alice@example.com      Laptop         1
# 1       1  1002     Bob Jones                       NaN  Headphones         2
# 2       2  1003  Charlie John       charlie#example.com  Smartphone         1
# 3       3  1004     David Lee     david.lee@example.com      Laptop         1
# 4       4  1005  Eve Martinez  eve.martinez@example.com  Smartwatch         3
# 5       5  1006  Frank Wright                       NaN      Tablet         1
# 6       7  1008    Hank Brown    hank.brown@example.com     Monitor         2
# 7       8  1009  Ivy Thompson                       NaN    Keyboard         2
# 8       9  1010    Jack Davis          jack@example.com       Mouse         5
# 9      10  1011   Alice Smith         alice@example.com      Laptop         1
# 10     11  1012    Kurt Evans    kurt.evans@example.com  Smartwatch       100
# 11     12  1013    Liam Adams    liam.adams@example.com  Headphones         2
# 12     13  1014     Mia Clark     mia.clark@example.com         NaN         1
# 13     14  1015   Nina Turner                       NaN      Tablet         1
# 14     15  1016  Oscar Harris  oscar.harris@example.com      Laptop         2
# 15     16  1017    Paul Young                 paulyoung     Monitor         2
# 16     17  1018   Quinn Lopez                       NaN  Smartphone         1
# 17     18  1019  Rachel Scott  rachel.scott@example.com    Keyboard         2
# 18     19  1020    Steve King    steve.king@example.com       Mouse         5
#
#      Price  Purchase Date  Delivery Status
# 0   1200.0     2024-09-15             True
# 1    150.0     2024-09-16             True
# 2    800.0     16/09/2024             True
# 3   1200.0     2024-09-17            False
# 4    600.0  17th Sep 2024             True
# 5    600.0     2024-09-18            False
# 6    300.0     09/19/2024             True
# 7    100.0     2024/09/20            False
# 8     50.0     2024-09-21             True
# 9   1200.0     2024-09-15             True
# 10   200.0     2024-09-22             True
# 11   150.0     2024-09-23            False
# 12     0.0     2024-09-24             True
# 13   600.0     24-09-2024             True
# 14  1200.0     2024-09-25             True
# 15   300.0     09/25/2024             True
# 16   800.0     2024-09-26            False
# 17   100.0     2024-09-27             True
# 18    50.0     2024-09-28             True

# %%
sns.boxplot(data = df2[['Price', 'Quantity']])
#Quantity still got outliers, need to do for quantity too
# Out:
# <Axes: >

# %%
min = df2['Quantity'].quantile(0) # min
Q1 = df2['Quantity'].quantile(0.25) # First Quartile
median = df2['Quantity'].quantile(0.50) # Second Quartile # median
Q3 = df2['Quantity'].quantile(0.75) # Third Quartile
max = df2['Quantity'].quantile(1) # max

print(f"Min: ", min)
print(f"Q1: ", Q1)
print(f"Median: ", median)
print(f"Q3: ", Q3)
print(f"Max: ", max)

IQR = Q3 - Q1

print(f"IQR: ", IQR)

# IQR method of outlier detection
lower = Q1 - IQR*1.5
upper = Q3 + IQR*1.5

print(f"Lower Price: ", lower)
print(f"Upper Price: ", upper)

# filter out the outliers
outliers = df2[(df2['Quantity'] < lower) | (df2['Quantity'] > upper)]
print(outliers)

df2 = df2[(df2['Quantity'] >= lower) & (df2['Quantity'] <= upper)].reset_index()
df2
# Out:
# Min:  1.0
# Q1:  1.0
# Median:  2.0
# Q3:  2.0
# Max:  100.0
# IQR:  1.0
# Lower Price:  -0.5
# Upper Price:  3.5
#     index    ID        Name                   Email     Product  Quantity  \
# 8       9  1010  Jack Davis        jack@example.com       Mouse         5
# 10     11  1012  Kurt Evans  kurt.evans@example.com  Smartwatch       100
# 18     19  1020  Steve King  steve.king@example.com       Mouse         5
#
#     Price Purchase Date  Delivery Status
# 8    50.0    2024-09-21             True
# 10  200.0    2024-09-22             True
# 18   50.0    2024-09-28             True
#     level_0  index    ID          Name                     Email     Product  \
# 0         0      0  1001   Alice Smith         alice@example.com      Laptop
# 1         1      1  1002     Bob Jones                       NaN  Headphones
# 2         2      2  1003  Charlie John       charlie#example.com  Smartphone
# 3         3      3  1004     David Lee     david.lee@example.com      Laptop
# 4         4      4  1005  Eve Martinez  eve.martinez@example.com  Smartwatch
# 5         5      5  1006  Frank Wright                       NaN      Tablet
# 6         6      7  1008    Hank Brown    hank.brown@example.com     Monitor
# 7         7      8  1009  Ivy Thompson                       NaN    Keyboard
# 8         9     10  1011   Alice Smith         alice@example.com      Laptop
# 9        11     12  1013    Liam Adams    liam.adams@example.com  Headphones
# 10       12     13  1014     Mia Clark     mia.clark@example.com         NaN
# 11       13     14  1015   Nina Turner                       NaN      Tablet
# 12       14     15  1016  Oscar Harris  oscar.harris@example.com      Laptop
# 13       15     16  1017    Paul Young                 paulyoung     Monitor
# 14       16     17  1018   Quinn Lopez                       NaN  Smartphone
# 15       17     18  1019  Rachel Scott  rachel.scott@example.com    Keyboard
#
#     Quantity   Price  Purchase Date  Delivery Status
# 0          1  1200.0     2024-09-15             True
# 1          2   150.0     2024-09-16             True
# 2          1   800.0     16/09/2024             True
# 3          1  1200.0     2024-09-17            False
# 4          3   600.0  17th Sep 2024             True
# 5          1   600.0     2024-09-18            False
# 6          2   300.0     09/19/2024             True
# 7          2   100.0     2024/09/20            False
# 8          1  1200.0     2024-09-15             True
# 9          2   150.0     2024-09-23            False
# 10         1     0.0     2024-09-24             True
# 11         1   600.0     24-09-2024             True
# 12         2  1200.0     2024-09-25             True
# 13         2   300.0     09/25/2024             True
# 14         1   800.0     2024-09-26            False
# 15         2   100.0     2024-09-27             True

# %%
sns.boxplot(data = df2[['Price', 'Quantity']])
# Out:
# <Axes: >

# %%
#pip install seaborn

# %%
import seaborn as sns

data = pd.Series([20, 20, 20, 23, 25, 30, 35, 40, 45, 50])

data.median()

#sns.histplot(data, bins = 10)

#sns.boxplot(data)

data.describe()
# Out:
# count    10.000000
# mean     30.800000
# std      11.143508
# min      20.000000
# 25%      20.750000
# 50%      27.500000
# 75%      38.750000
# max      50.000000
# dtype: float64
