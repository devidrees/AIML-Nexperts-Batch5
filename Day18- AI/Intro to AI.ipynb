# %% [markdown]
# ## Machine Learning
# - What is AI?
#         - system or machine that can **"mimic human intelligance & behaviour"**
#         -

# %% [markdown]
# Things to do
# - Machine Learning
# - Types:
#     - Supervised Learning
#     - Unsupervised Learning
